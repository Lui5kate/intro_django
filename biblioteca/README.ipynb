# %% [markdown]
# pip install --upgrade pip
# sudo apt install python3-virtualenv
# pip install virtualenv
# pip freeze
# CREAR UNA CARPETA PARA LOS ENTORNOS
# cd entornos/
# virtualenv django_2_0
# source django_2_0/bin/activate
# pip freeze
# deactivate
# source ~/entornos/django_2_0/bin/activate
# pip install django==2.0.6
# CREAMOS UNA CARETA DONDE VAMOS ALMACENAR NUESTRO PROYECTO
# django-admin startproject biblioteca
#
# DEFINICIÓN DE ARCHIVOS
#
# manage.py
# ARCHIVO PARA CREAR APLICACIONES CON DJANGO, SUPERUSUARIOS.
# CONFIGURACIONES DE NUESTRO PROYECTO EN biblioteca.settings
# DJANGO RECONOCE ESTE ARCHIVO COMO INDICADOR PARA INICIAR LA APLICACIÓN __init__.py
# import os ACCEDE A LAS CARPETAS DE NUESTRO PROYECTO
# SECRET KEY SE CUENTA CON UNA LLAVE SECRETA PARA LA APLICACIÓN
# DEBUG = True MUESTRA LOS ERRORES, NO SE DEBE TENER EN TRUE EN PRODUCCIÓN
# ALLOWED_HOST = [] SE COLOCAN LAS IPS O DOMINIOS EN LAS CUALES SE PUEDEN ACCEDER AL PROYECTO
# INSTALLED_APPS = [] UNA APLICACIÓN ES UNA ABSTRACCIÓN, QUIERE DECIR QUE SEPARA EL DESARROLLO
# MIDDLEWARE = [] COMUNICACION DE LO QUE ENVIE EL SERVIDOR AL CLIENTE Y VICEVERSA, EL MIDDLEWARE ESTÁ EN MEDIO PARA
# MEDIAR QUE NO SE SALTEN JERARQUIAS, NIVELES, ETC.
# ROOT_URLCONF = RUTAS PRINCIPALES DE TODO NUESTRO PROYECTO, HACE REFERENCIA EN biblioteca.urls
# TEMPLATES = [] DJANGO USA UN SISTEMA DE PLANTILLAS Y AQUÍ SE ALMACENAN
# DIRS = [] AQUI SE ALOJAN TODOS LOS DIRECTORIOS DE NUESTRO PROYECTO
# APP_DIRS = True CUANDO UN CLIENTE HAGA UNA PETICION DE UNA PLANTILLA O DE UN TEMPLATE HTML, DJANGO VA A BUSCAR
# EN TODO NUESTRO PROYECTO SI ESTA EN True
# OPTIONS : {} LAS OPCIONES PARA PROCESAR NUESTROS TEMPLATES
# WSGI_APPLICATION EN PROCUCCIÓN INDICA COMO PUEDE LEVANTAR LA APLCIACION, HACE REFERENCIA A
# biblioteca.wsgi.application
# DATABASES AQUI SE COLOCAN LAS CONFIGURACIONES DE LAS BASES DE DATOS
# PASSWORD VALIDATION VALIDACIONES PARA LAS CONTRASEÑAS DE LOS USUARIOS
# INTERNATIONALIZATION CONFIGURACIONES PARA LENGUAJE, TIMEZONE, ETC.
# STATIC FILES PARA GUARDAR ARCHIVOS (CSS, JavaScript, Images)
# urls.py
# TODO ARCHIVO DE URL DEBE TENER UN urlpatterns
# DJANGO TRABAJA CON EL MODELO VISTA TEMPLATE
# wsgi.py
# DEBE TENER EL MISMO SETTINGS EN WSGI.PY Y MANAGE.PY
#
# CREAR UNA APLICACION DJANGO
#
# CREAR CARPETA LLAMADA APPS
# ENTRAR CON TERMINAL A LA CARPETA
# django-admin startapp libro
# AGREGAMOS LA APP EN settings.py EJ: 'apps.libro',
# LA CARPETA migrations SIRVE PARA LAMACENAR LAS CONFIGURACIONES PARA HACER UNA MIGRACIÓN
# MIGRACIÓN DONDE MANDAMOS UNA ESTRUCTURA O UNA TABLA CREADA CON SINTAXIS DE PYTHON A NUESTRO GESTOR DE BASES DE DATOS
# admin.py VAMOS A REGISTRAR MODELOS O TABLAS
# models.py AQUI SE CREAN LOS MODELOS, MODELOS = CLASE Y QUE REPRESENTA A UNA TABLA EN UNA BASE DE DATOS
# test.py DJANGO TRAE CODIGO PARA HACER TESTEO DE NUESTROS MODELOS Y LOGICA
# views.py DONDE SE CREA LA LOGICA PARA LOS MODELOS
#
# MODELO VISTA CONTROLADOR
#
# USUARIO -> VISTA -> CONTROLADOR -> MODELO
# MODELO -> CONTROLADOR -> VISTA -> MODELO
#
# UN USUARIO EL CUAL ES LA PERSONA QUE INTERACTUA CON LA VISTA QUE PUEDE VER, LA VISTA ESTÁ CONECTADA A UN CONTROLADOR,
# EL CONTROLADOR DECIDE SI SE HARÁ UNA MODIFICACIÓN EN LA BASE DE DATOS, PARA ELLO, SE CONECTA CON EL MODELO,
# A TRAVES DEL MODELO, EL CONTROLADOR TIENE ACCESO A LA BASE DE DATOS Y SE RETORNA LO DESEADO DE NUEVO AL CONTROLADOR,
# EL CONTROLADOR DEVUELVE LO QUE RECIBIÓ A LA VISTA, Y LA VISTA RETORNA DE UNA MANERA ENTENDIBLE AL USUARIO.
#
# MODELO VISTA TEMPLATE
#
# MODELO -> URL -> VISTA -> MODELO
# MODELO -> VISTA -> TEMPLATE -> USUARIO
#
# VISTA TRAE LA LOGICA DE PROGRAMACIÓN Y TIENE ASOCIADO UN MODELO
# EL TEMPLATE TRAE COMO SE VA A MOSTRAR MAS NO CÓMO
#
# CREACION DE MODELOS
#
# EN models.py con SQLITE3
# PRIMERO CREAMOS LOS MODELOS
# class Autor(models.Model):
#     id = models.AutoField(primary_key=True)
#     nombre = models.CharField(max_length=200, blank=False, null=False)
#     apellidos = models.CharField(max_length=220, blank=False, null=False)
#     nacionalidad = models.CharField(max_length=100, blank=False, null=False)
#     descripcion = models.TextField(blank=False, null=False)
# VAMOS A LA TERMINAL Y COLOCAMOS python manage.py makemigrations
# LA RESPUESTA SERÁ ALGO COMO ESTO
# Migrations for 'libro':
#   apps/libro/migrations/0001_initial.py
#     - Create model Autor
# EN LA TERMINAL CORREMOS EL COMANDO python manage.py migrate PARA CORRER LA MIGRACIÓN
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, libro, sessions
# Running migrations:
#   Applying contenttypes.0001_initial... OK
#   Applying auth.0001_initial... OK
#   Applying admin.0001_initial... OK
#   Applying admin.0002_logentry_remove_auto_add... OK
#   Applying contenttypes.0002_remove_content_type_name... OK
#   Applying auth.0002_alter_permission_name_max_length... OK
#   Applying auth.0003_alter_user_email_max_length... OK
#   Applying auth.0004_alter_user_username_opts... OK
#   Applying auth.0005_alter_user_last_login_null... OK
#   Applying auth.0006_require_contenttypes_0002... OK
#   Applying auth.0007_alter_validators_add_error_messages... OK
#   Applying auth.0008_alter_user_username_max_length... OK
#   Applying auth.0009_alter_user_last_name_max_length... OK
#   Applying libro.0001_initial... OK
#   Applying sessions.0001_initial... OK
# PARA VALIDAR LA MIGRACIÓN...
#
# CORRER SERVIDOR PARA PRUEBA DE MIGRACIÓN
#
# EN TERMINAL CORREMOS python manage.py runserver
# Performing system checks...
#
# System check identified no issues (0 silenced).
# March 01, 2024 - 05:20:08
# Django version 2.0.6, using settings 'biblioteca.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# ABRIR UN NAVEGADOR CON LA DIRECCIÓN localhost:8000
# DESPUÉS localhost:8000/admin PARA ARIR LA PAGINA DE ADMIN
#
# CREAR SUPERUSUARIOS
#
# CON EL SERVIDOR DESCATIVADO CORREMOS python manage.py createsuperuser
# INGRESAMOS NOMBRE, CORREO Y CONTRASEÑAS
#
# CONECTAR BASE DE DATOS MYSQL CON DJANGO
#
# INSTALAR LA LIBRERÍA pip install mysqlclient
#
# sudo apt-get update
# sudo apt-get install python-dev default-libmysqlclient-dev
# sudo apt-get install python3-dev
# pip install mysqlclient
# python manage.py migrate
# CREO UN NUEVO PROYECTO EN DJANGO django-admin startproject django_mysql
# O SI YA SE TIENE UN PROYECTO, ACTIVARLO
# CREO MI BASE DE DATOS EN MYSQL EN BLANCO
# CORREMOS python manaege.py migrate
# CREAMOS A MODO DE PRUEBA UN SUPERUSUARIO CON python manage.py createsuperuser
# CORREMOS NUESTRA APLICACION CON python manage.py runserver PARA PROBAR ENTRAR AL PORTAL
# DETENEMOS EL SERVIDOR
# AHORA CREAMOS UN MODELO A MODO DE EJEMPLO, PRIMERO VAMOS A LA CARPTETA APPS Y DESPUES CON django-admin startapp contacto
# VAMOS A settings.py Y EN INSTALLED_APPS AGREGAMOS 'apps.contacto',
# VAMOS A CARPETA CONTACTO Y ARCHIVO models.py
# AGREGAMOS UN MODELO SENCILLO EN models.py
# from django.db import models
#
# # Create your models here.
# class Contacto(models.Model):
#     nombre = models.CharField(blank=True, max_length=100, verbose_name='Nombre')
#     apellido = models.CharField(blank=True, max_length=100, verbose_name='Apellido')
#     correo = models.EmailField(unique=True, max_length=100, verbose_name='Correo')
#     edad = models.IntegerField(null=True, blank=True)
#
#     def __str__(self):
#         return self.nombre
#
#     class Meta:
#         ordering = ['nombre']
#         verbose_name = 'Contacto'
#         verbose_name_plural = 'Contactos'
#
# EN admin.py LO AGREGAMOS PARA PODER VISUALIZARLO
# from django.contrib import admin
# from .models import Contacto
#
# # Register your models here.
#
# admin.site.register(Contacto)
#
# HAEMOS LA MIGRACIÓN POR CMD. REGRESAMOS A LA CARPETA BIBLIOTECA Y LUEGO CON python manage.py makemigrations
# Migrations for 'contacto':
#   apps/contacto/migrations/0001_initial.py
#     - Create model Contacto
#
# LO MANDAMOS A LA BASE DE DATOS CON python manage.py migrate
# Operations to perform:
#   Apply all migrations: admin, auth, contacto, contenttypes, libro, sessions
# Running migrations:
#   Applying contacto.0001_initial... OK
#
# IMPORTANTE: CADA QUE SE HAGA UN CAMBIO EN ALGÚN MODELO HAY QUE CORRER python manage.py makemigrations Y python manage.py migrate
#
# CREAR UN FORMULARIO DE ENTRADA DE DATOS
#
# SE CREARÁ PARA EL MODELO AUTOR CREANDO UN ARCHIVO NUEVO LLAMADO forms.py
# from django import forms
# from .models import Autor
#
# class AutorForm(forms.ModelForm):
#     class Meta:
#         model = Autor
#         fields = ['nombre','apellidos','nacionalidad','descripcion']
#
# ENLAZAR URLS DE APLICACION CON URLS DE PROYECTOS
#
# CREAR EN LA APLICACION UNA CARPETA LLAMADA urls.py PARA PODER LIGARLA CON EL ARCHIVO urls.py QUE SE TIENE GLOBALMENTE
# AHORA VAMOS AL ARCHIVO urls.py GLOBAL DENTRO DE LA SUBCARPETA BIBLIOTECA, EN EL IMPORT DEL PATH AGREGAMOS ,include
# Y EN URLPATTERNS ESCRIBIMOS path('libro/', include(('apps.libro.urls, 'libro')))
#
# EN EL ARCHIVO urls.py DE LA APLICACION AGREGAMOS
# from django.urls import path
#
# urlpatterns =  []
#
# EN EL ARCHIVO views.py DE LA APLICACION CREAREMOS UNA VISTA SENCILLA
# from django.shortcuts import render
#
# # Create your views here.
# def Home(request):
#     return render(request, 'libro/index.html')
#
# REGRESAMOS AL ARCHIVO urls.py DE LA APLICACIÓN Y AGREGAMOS EL HOME DEL ARCHIV DE VIEWS DE LA SIGUIENTE FORMA
# from django.urls import path
# from .views import Home
#
# urlpatterns =  [
#     path('', Home, name='index')
# ]
# AGREGAMOS UNA NUEVA CARPETA LLAMADA TEMPLATES EN LA CARPETA RAÍZ Y LUEGO CREAMOS OTRA DENTRO DE LA CAPRPETA NUEVA QUE SE LLAME IGUAL A
# NUESTRA APP EN ESTE CASO 'LIBRO', POR ULTIMO CREAMOS EL ARCHIVO INDEX.HTML
#
# FALTA UN ARCHIVO DE CONFIGURACIÓN EN SETTINGS.PY
# EN LA SECCIÓN DE TEMPLATES AGREGAMOS LA DIRECCION DE LAS CARPETAS 'DIRS': ['templates'],
# RECARGAMOS PAGINA Y YA SE VERÁ EL CONTENIDO HTML DE LA PAGINA
#
# 12.- Curso Django 2 | Vistas basadas en funciones: Crear Autor
#
# IMPORTAMOS LA FUNCION HOME EN EL ARCHIVO DE URLS GLOBAL Y AÑADIMOS EL PATH CON EL INDEX CREADO ANTERIORMENTE
# from django.contrib import admin
# from django.urls import path, include
# from apps.libro.views import Home
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('libro/', include(('apps.libro.urls', 'libro')))
#     path('home/', Home, name='index')
# ]
#
# EN EL ARCHIV URLS DE LA APLICACION B0RRAMOS EL PATH PUESTO QUE YA NO ES NECESARIO
# from django.urls import path
#
# urlpatterns =  [
#
# ]
#
# MODIFICAMOS EL ARCHIVO DE VIEWS EN LA APLICACION A LA CARPETA RAIZ
# from django.shortcuts import render
#
# # Create your views here.
# def Home(request):
#     return render(request, 'index.html')
#
# Y SACAMOS EL ARCHIVO INDEX A LA CARPETA DE TEMPLATES
#
# 12.- Curso Django 2 | Vistas basadas en funciones: Crear Autor
#
# PROTOCOLO HTTP, METODO GET CUANDO QUEREMOS OBTENER INFO DEL SERVIDOR O BDD
# ENVIARLE DATOS AL SERVIDOR ES CON POST
#
# AGREGAMOS UNA FUNCIÓN PAR CREAR UN AUTOR DE ESTA FORMA EN EL ARCHIVO VIEWS.PY DE LIBRO
# BASICAMENTE EL SIGUIENTE CODIGO VALIDA SI EL METODO ENVIADO ES POST O GET, EN CASO DE QUE SEA POST
# HACE EL ENVÍO DE INFORMACIÓN YA PREVIAMENTE LLENADA REDIRIGE A INDEX, Y EN CASO CONTRARIO MUESTRA EL FORMULARIO CON EL RENDER CREADO PREVIAMENTE
# def crearAutor(request):
#     if request.method == 'POST':
#         autor_form = AutoForm(request.POST)
#         if autor.form.is_valid():
#             autor_form.save()
#             return redirect('index')
#     else:
#         autor_form = AutoForm()
#     return render(request, 'libro/crear_autor.html', {'autor_form': autor_form})
#
# VAMOS AL ARCHIVO URLS.PY DE LIBRO, Y COLOCAMOS UNA RUTA PARA CREAR AUTOR
# from django.urls import path
# from .views import crearAutor
#
# urlpatterns =  [
#     path('crear_autor/', crearAutor, name='crear_autor')
# ]
#
# CREAMOS UN ARCHVIVO LLAMADO CREAR_AUTOR.HTML EN TEMPLATES/LIBRO CON EL SIGUIENTE HTML
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Creación de Autores</title>
# </head>
# <body>
#     <form method="POST">
#         {{autor_form.as_p}}
#         <button type="submit">Crear</button>
#     </form>
# </body>
# </html>
#
# IMPORTAMOS EN VIEWS.PY EL AUTOFORM
# from .forms import AutoForm
#
# PROBAMOS INICIANDO EL SERVER Y ESCRIBIENDO EL URL http://localhost:8000/libro/crear_autor/
#
# 13.- Curso Django 2 | Sistema de plantillas de Django
#
# HEREDAR PLANTILLAS HTML
# TAG {% %} ES PARA HEREDAR CODIGO HTML A OTRAS PAGINAS
# QUEDARIA EL ARCHIVO CREAR_USUARIO.PY DE ESTA FORMA
# {% extends 'index.html' %}
# {%block titulo%}
#     Creación de Autores
# {%endblock titulo%}
# {%block body%}
#     <form method="POST">
#         {% csrf_token %}
#         {{autor_form.as_p}}
#         {%if autor_form %}
#         {%end if %}
#         {% for autor in autor_form %}
#             {{}}
#         {% endfor %}
#         <button type="submit">Crear</button>
#     </form>
# {%endblock body%}
#
# 14.- Curso Django 2 | Consultas básicas en Django
#
# ORM - SINTAXIS SQL EN EL LENGUAJE QUE ESTEMOS TRABJANDO
#
# ABRIMOS EL SHELL DESDE TERMINAL EN NUESTRO PROYECTO
# python manage.py shell
# IMPORTAMOS LA FUNCION DEL ARCHIVO MODELS.PY DE LA APLICACION LIBRO from apps.libro.models import Autor
#
# >>> from apps.libro.models import Autor
# PRIMERA FORMA DE GUARDAR UN NUEVO REGISTRO
# >>> Autor.objects.create(nombre="Juan", apellidos="Diaz", nacionalidad="MEX", descripcion="autor nuevo")
# <Autor: Juan>
#
# SEGUNDA FORMA DE GUARDAR UN REGISTRO
# >>> nuevo = Autor(nombre="Eduardo",apellidos="Favio",nacionalidad="Peru",descripcion="otro nuevo autor")
# >>> nuevo.save()
#
# LISTAR TODOS LOS ELEMENTOS, NOTA IMPROTANTE: EN DJANGO PARA PODER TRABJAR CON LAS CONSULTAS, SOLO ADMITE TRABAJAR CON UN SOLO DATO DE RETORNO
# POR LO QUE PODEMOS HACER CONSULTAS O ALGÚN TRATAMIENTO POSTERIOR
# >>> Autor.objects.all()
# <QuerySet [<Autor: asdfg>, <Autor: Eduardo>, <Autor: Juan>, <Autor: Lau>, <Autor: Luis Armando>, <Autor: Luis Armando>, <Autor: PRUEBA>]>
#
# LISTAR TODOS LOS ELEMENTOS CON NACIONALIDAD MEX
# >>> Autor.objects.filter(nacionalidad = "MEX")
# <QuerySet [<Autor: Juan>, <Autor: Lau>]>
#
# LISTAR TODOS LOS ELEMENTOS CON NACIONALIDAD MEX Y ID 5
# >>> Autor.objects.filter(nacionalidad = "MEX",id = 5)
# <QuerySet [<Autor: Lau>]>
#
# 15.- Curso Django 2 | Vistas basadas en funciones: Listar Autor
#
# CREAMOS UNA FUNCION EN VIEWS.PY DE LISTAR AUTORES
#
# 16.- Curso Django 2 | PATH, RE PATH: Manejo de URLS
#
# 17.- Curso Django 2 | Vistas basadas en funciones: Editar Autor
